# %%
import torch


print(f"Có GPU không? {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Tên GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Có GPU không? True
# Tên GPU: NVIDIA GeForce RTX 5060 Laptop GPU

# %%
import pandas as pd

file_path = r'../../src/data/urlhaus_recent.csv'
url_data = pd.read_csv(file_path, encoding_errors='ignore', skiprows=8)
url_data.info()

print(url_data.isnull().sum())
print("\nPhân phối nhãn:")
print(url_data['threat'].value_counts())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 18696 entries, 0 to 18695
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   # id          18696 non-null  int64
#  1   dateadded     18696 non-null  str
#  2   url           18696 non-null  str
#  3   url_status    18696 non-null  str
#  4   last_online   14314 non-null  str
#  5   threat        18696 non-null  str
#  6   tags          17607 non-null  str
#  7   urlhaus_link  18696 non-null  str
#  8   reporter      18696 non-null  str
# dtypes: int64(1), str(8)
# memory usage: 4.0 MB
# # id               0
# dateadded          0
# url                0
# url_status         0
# last_online     4382
# threat             0
# tags            1089
# urlhaus_link       0
# reporter           0
# dtype: int64
#
# Phân phối nhãn:
# threat
# malware_download    18696
# Name: count, dtype: int64

# %%
file_path = r'../../src/data/processed_url_update.csv'
url_data = pd.read_csv(file_path, encoding_errors='ignore')

mean_benign_part = url_data[url_data['type'] == 'benign']['number_of_part'].mean()
mean_benign_scheme = url_data[url_data['type'] == 'benign']['has_scheme'].mean()
mean_benign_levenshtein = url_data[url_data['type'] == 'benign']['normalized_levenshtein_domain'].mean()
print(f"mean value of number of part in benign: {mean_benign_part}")
print(f"mean value of number of url having scheme in benign: {mean_benign_scheme}")
print(f"mean value of levenshtein of benign url: {mean_benign_levenshtein}")
print()

mean_defacement_part = url_data[url_data['type'] == 'defacement']['number_of_part'].mean()
mean_defacement_scheme = url_data[url_data['type'] == 'defacement']['has_scheme'].mean()
mean_defacement_levenshtein = url_data[url_data['type'] == 'defacement']['normalized_levenshtein_domain'].mean()
print(f"mean value of number of part in defacement: {mean_defacement_part}")
print(f"mean value of number of url having scheme in defacement: {mean_defacement_scheme}")
print(f"mean value of levenshtein of defacement url: {mean_defacement_levenshtein}")
print()

mean_malware_part = url_data[url_data['type'] == 'malware']['number_of_part'].mean()
mean_malware_scheme = url_data[url_data['type'] == 'malware']['has_scheme'].mean()
mean_malware_levenshtein = url_data[url_data['type'] == 'malware']['normalized_levenshtein_domain'].mean()
print(f"mean value of number of part in malware: {mean_malware_part}")
print(f"mean value of number of url having scheme in malware: {mean_malware_scheme}")
print(f"mean value of levenshtein of malware url: {mean_malware_levenshtein}")
print()

mean_phishing_part = url_data[url_data['type'] == 'phishing']['number_of_part'].mean()
mean_phishing_scheme = url_data[url_data['type'] == 'phishing']['has_scheme'].mean()
mean_phishing_levenshtein = url_data[url_data['type'] == 'phishing']['normalized_levenshtein_domain'].mean()
print(f"mean value of number of part in phishing: {mean_phishing_part}")
print(f"mean value of number of url having scheme in phishing: {mean_phishing_scheme}")
print(f"mean value of levenshtein of phishing url: {mean_phishing_levenshtein}")
print()
# Out:
# C:\Users\AD\AppData\Local\Temp\ipykernel_26472\812510562.py:2: DtypeWarning: Columns (0: scheme, 1: query, 2: fragment) have mixed types. Specify dtype option on import or set low_memory=False.
#   url_data = pd.read_csv(file_path, encoding_errors='ignore')
# mean value of number of part in benign: 2.252119232988323
# mean value of number of url having scheme in benign: 0.08263899108392139
# mean value of levenshtein of benign url: 0.3507315093320983
#
# mean value of number of part in defacement: 3.5698186756793184
# mean value of number of url having scheme in defacement: 1.0
# mean value of levenshtein of defacement url: 0.0018575758159199486
#
# mean value of number of part in malware: 3.046137925648235
# mean value of number of url having scheme in malware: 0.9763745704467354
# mean value of levenshtein of malware url: 0.10136276026769234
#
# mean value of number of part in phishing: 2.1176433979877607
# mean value of number of url having scheme in phishing: 0.2775645679908723
# ...

# %%
# Print information of URLs which have has_username == 1 and has_password == 1
filtered_data = url_data[(url_data['has_username'] == 1) & (url_data['has_password'] == 1)]
print(filtered_data)
# Out:
#                                                       url      type  \
# 233767  http://%C3%87%C3%AB%C3%89%C3%A8%C3%96%C3%83%C3...   malware
# 355361  http://%C3%87%C3%AB%C3%89%C3%A8%C3%96%C3%83%C3...   malware
# 529835                      http://mailto:ajuda@iti.itau/  phishing
#
#         url length scheme                                             netloc  \
# 233767         157   http  %C3%87%C3%AB%C3%89%C3%A8%C3%96%C3%83%C3%95%C3%...
# 355361         157   http  %C3%87%C3%AB%C3%89%C3%A8%C3%96%C3%83%C3%95%C3%...
# 529835          29   http                              mailto:ajuda@iti.itau
#
#        path query fragment subdomain     domain  ...  has_uuid_path  \
# 233767    /   NaN      NaN       NaN  juhaoyong  ...              0
# 355361    /   NaN      NaN       NaN  juhaoyong  ...              0
# 529835    /   NaN      NaN       NaN        iti  ...              0
#
#         download_param  free_host  free_host_download  suspicious suffix  \
# ...
